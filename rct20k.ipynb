# %%
# !git clone https://github.com/sachlatis/fine-tune-bert-on-biomed.git
# %cd /kaggle/working/fine-tune-bert-on-biomed/data
# !unzip train.zip
# %cd /kaggle/working/fine-tune-bert-on-biomed
# !mkdir model
# %cd /kaggle/working/fine-tune-bert-on-biomed/model
# !touch pytorch_model.bin
# !touch config.json
# !touch vocab.txt
# %cd /kaggle/working/fine-tune-bert-on-biomed/src
# Out:
# Cloning into 'fine-tune-bert-on-biomed'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (132/132), done.
# remote: Total 143 (delta 64), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (143/143), 12.00 MiB | 11.16 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# /kaggle/working/fine-tune-bert-on-biomed/data
# Archive:  train.zip
#   inflating: train.txt
#    creating: __MACOSX/
#   inflating: __MACOSX/._train.txt
# /kaggle/working/fine-tune-bert-on-biomed
# /kaggle/working/fine-tune-bert-on-biomed/model
# /kaggle/working/fine-tune-bert-on-biomed/src

# %%
# !python3 sentence_classifier.py --mode train

# %%
# !zip -r /kaggle/working/biomed.zip /kaggle/working/fine-tune-bert-on-biomed/model

# %%
from IPython.display import FileLink
FileLink(r'/kaggle/working/biomed.zip')

# %%
# !python3 sentence_classifier.py --mode eval
