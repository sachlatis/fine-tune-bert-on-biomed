# %% [markdown]
# # Init

# %%
# !git clone https://github.com/sachlatis/rct.git
# %cd /kaggle/working/rct/data
# !unzip train.zip
# !mkdir /kaggle/working/rct/model
# %cd /kaggle/working/rct/model
# !touch pytorch_model.bin
# !touch config.json
# %cd /kaggle/working/rct/src

# %% [markdown]
# # Train Model

# %%
# !python3 sentence_classifier.py --mode train

# %%
# !zip -r /kaggle/working/rct.zip /kaggle/working/rct/model

# %% [markdown]
# # Eval Model

# %%
# !python3 sentence_classifier.py --mode eval
